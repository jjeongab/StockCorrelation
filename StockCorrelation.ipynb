# %%
import yfinance as yf 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 10.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.3/229.3 kB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 17.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 18.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 9.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Apple = yf.download("AAPL", start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.487532  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.498750  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.395379  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.383554  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.425995  447610800

# %%
a = [1, 2, 3,5]

# %%
ticker = ["SPY", "AAPL", "KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.793243   87.791801    7.643214  28.520000
# 2010-01-05    6.498750  18.565893   88.024162    7.656429  28.174999
# 2010-01-06    6.395381  18.559315   88.086159    7.534643  28.165001
# 2010-01-07    6.383556  18.513182   88.458000    7.520714  28.094999
# 2010-01-08    6.425994  18.170532   88.752335    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850586  49.557598  355.649139  131.970001  53.439999
# 2020-12-28  134.494766  50.225292  358.704529  136.690002  54.160000
# 2020-12-29  132.703964  50.197475  358.020233  134.869995  54.130001
# 2020-12-30  131.572495  50.484951  358.531006  133.720001  54.439999
# 2020-12-31  130.559006  50.855885  360.352661  132.690002  54.840000
#
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
# ...

# %%
stocks.to_csv("stocksYT.csv")

# %%
stocks = pd.read_csv("stocksYT.csv", header = [0, 1])

# %%
stocks = pd.read_csv("stocksYT.csv", header = [0, 1], index_col = [0], parse_dates = [0])

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.793243   87.791801    7.643214  28.520000
# 2010-01-05    6.498750  18.565893   88.024162    7.656429  28.174999
# 2010-01-06    6.395381  18.559315   88.086159    7.534643  28.165001
# 2010-01-07    6.383556  18.513182   88.458000    7.520714  28.094999
# 2010-01-08    6.425994  18.170532   88.752335    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850586  49.557598  355.649139  131.970001  53.439999
# 2020-12-28  134.494766  50.225292  358.704529  136.690002  54.160000
# 2020-12-29  132.703964  50.197475  358.020233  134.869995  54.130001
# 2020-12-30  131.572495  50.484951  358.531006  133.720001  54.439999
# 2020-12-31  130.559006  50.855885  360.352661  132.690002  54.840000
#
# ...

# %%
#convert mult index to one tuple
stocks.column = stocks.columns.to_flat_index()
stocks.column
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.793243   87.791801    7.643214  28.520000
# 2010-01-05    6.498750  18.565893   88.024162    7.656429  28.174999
# 2010-01-06    6.395381  18.559315   88.086159    7.534643  28.165001
# 2010-01-07    6.383556  18.513182   88.458000    7.520714  28.094999
# 2010-01-08    6.425994  18.170532   88.752335    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850586  49.557598  355.649139  131.970001  53.439999
# 2020-12-28  134.494766  50.225292  358.704529  136.690002  54.160000
# 2020-12-29  132.703964  50.197475  358.020233  134.869995  54.130001
# 2020-12-30  131.572495  50.484951  358.531006  133.720001  54.439999
# 2020-12-31  130.559006  50.855885  360.352661  132.690002  54.840000
#
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.793243   87.791801    7.643214  28.520000
# 2010-01-05    6.498750  18.565893   88.024162    7.656429  28.174999
# 2010-01-06    6.395381  18.559315   88.086159    7.534643  28.165001
# 2010-01-07    6.383556  18.513182   88.458000    7.520714  28.094999
# 2010-01-08    6.425994  18.170532   88.752335    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850586  49.557598  355.649139  131.970001  53.439999
# 2020-12-28  134.494766  50.225292  358.704529  136.690002  54.160000
# 2020-12-29  132.703964  50.197475  358.020233  134.869995  54.130001
# 2020-12-30  131.572495  50.484951  358.531006  133.720001  54.439999
# 2020-12-31  130.559006  50.855885  360.352661  132.690002  54.840000
#
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.604148    32.722795   183.435247    33.777537    41.320121
# std      24.647222     8.314333    70.233048    24.572747     6.808527
# min       5.821835    16.635138    79.874092     6.858929    25.014999
# 25%      15.221352    27.030157   115.753853    17.484285    37.660000
# 50%      24.581589    32.275932   177.317780    26.987499    41.759998
# 75%      40.985558    38.229046   243.770477    43.007500    45.549999
# max     134.494766    53.916512   360.352661   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
stocks.loc[:, "Close"]
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.plot(figsize = (15,8), fontsize = 12)
plt.legend(fontsize =12)
plt.show()

# %%
normClose = close.div(close.iloc[0]).mul(100)

# %%
normClose
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
normClose.plot(figsize = (15,8), fontsize = 12)
plt.legend(fontsize =12)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl
aapl.shift(periods = 1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
aapl["% Change"]= aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151
# 2010-01-08    7.570714    7.520714  0.050000  1.006648
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712
# 2020-12-28  136.690002  131.970001  4.720001  1.035766
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297
#
# [2769 rows x 4 columns]

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods =1 )
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl["% Change 2"] = aapl.AAPL.pct_change(periods = 1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2  \
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
#             % Change 3
# Date
# ...

# %%
del aapl["Diff2"]

# %%
del aapl["% Change"]

# %%
aapl.rename(columns = {"% Change 2": "Change"}, inplace = True)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff    Change  % Change 3
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893         NaN
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632   -1.420489
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871   -1.772563
# 2010-01-08    7.570714    7.520714  0.050000  0.664833    0.478733
# ...                ...         ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224    0.068241
# 2020-12-28  136.690002  131.970001  4.720001  3.576571    4.375378
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485    2.197464
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668   -2.172801
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265   -1.616366
#
# [2769 rows x 5 columns]

# %%
aapl.AAPL.resample("M").last() #retrieves montly value on M and only last day of month
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample("BM").last().pct_change(periods = 1).mul(100) #retrieves last business days
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
del aapl["lag1"]
del aapl["Diff"]
del aapl["Change"]
del aapl["% Change 3"]

# %%
ret = aapl.pct_change().dropna()

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2768 entries, 2010-01-05 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2768 non-null   float64
# dtypes: float64(1)
# memory usage: 43.2 KB

# %%
ret.plot(kind = "hist", figsize = (12, 8), bins= 100)
plt.show()

# %%
daily_ret_mean = ret.mean()

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)

# %%
std_daily
# Out:
# AAPL    0.017843
# dtype: float64

# %%
annual_mean_ret = daily_ret_mean * 252
annual_mean_ret
# Out:
# AAPL    0.300134
# dtype: float64

# %%
annual_var_return = var_daily * 252
annual_var_return
# Out:
# AAPL    0.080226
# dtype: float64

# %%
annual_std_returns = np.sqrt(annual_var_return)
annual_std_returns
# Out:
# AAPL    0.283242
# dtype: float64

# %%
annual_std_returns
# Out:
# AAPL    0.283242
# dtype: float64

# %%
tickers = ["SPY", "AAPL", "KO", "IBM", "DIS", "MSFT"]

# %%
stocks = yf.download(tickers, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks
# Out:
#              Adj Close                                                 \
#                   AAPL         DIS         IBM         KO        MSFT
# Date
# 2010-01-04    6.487535   27.933924   78.345863  18.793242   23.522568
# 2010-01-05    6.498750   27.864233   77.399475  18.565897   23.530165
# 2010-01-06    6.395379   27.716166   76.896667  18.559317   23.385765
# 2010-01-07    6.383554   27.724876   76.630486  18.513187   23.142561
# 2010-01-08    6.425995   27.768423   77.399475  18.170528   23.302162
# ...                ...         ...         ...        ...         ...
# 2020-12-24  129.850601  173.729996  104.185272  49.557602  217.364548
# 2020-12-28  134.494797  178.860001  104.293884  50.225288  219.521149
# 2020-12-29  132.703995  177.300003  103.441628  50.197472  218.730698
# 2020-12-30  131.572479  181.169998  103.892830  50.484959  216.320419
# 2020-12-31  130.559021  181.179993  105.179573  50.855888  217.042526
#
# ...

# %%
close = stocks.loc[:, "Close"].copy()

# %%
normClose = close.div(close.iloc[0]).mul(100)

# %%
normClose.plot(figsize = (12, 8), fontsize = 12) #plotting the graph 
plt.legend(fontsize = 12) #ticker symbols
plt.show() #showing the graph

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS   2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM   2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO    2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT  2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY   2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]

# %%
summary
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# DIS   0.000749  0.015717
# IBM   0.000082  0.014132
# KO    0.000298  0.011088
# MSFT  0.000841  0.016012
# SPY   0.000491  0.010909

# %%
summary["mean"] = summary["mean"] * 252
summary["std"] = summary["std"] * np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# DIS   0.188696  0.249504
# IBM   0.020648  0.224345
# KO    0.075091  0.176009
# MSFT  0.211915  0.254185
# SPY   0.123754  0.173170

# %%
summary.plot.scatter(x = "std", y = "mean",figsize = (12, 8), s = 100, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy = (summary.loc[i,"std"]+0.002, summary.loc[i, "mean"] + 0.002), size =15)
plt.xlabel("Annual risk(std)", fontsize =15)
plt.ylabel("Annual return", fontsize = 15)
plt.title("Risk/return", fontsize = 25)
plt.show()

# %%
fruits = ["apple", "banana", "mango"]
for i in fruits:
    print(i)
# Out:
# apple
# banana
# mango

# %% [markdown]
# # Correlation and Covariance

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
#ovariance measures the direction of the relationship between two variables. A positive covariance means that both variables tend to be high or low at the same time. A negative covariance means that when one variable is high, the other tends to be low.
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000318  0.000115  0.000110  0.000067  0.000158  0.000128
# DIS   0.000115  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM   0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO    0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT  0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY   0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
import seaborn as sns

# %%
plt.figure(figsize = (12, 8))
sns.set(font_scale = 1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws = {"size": 15}, vmax = 0.6)
plt.show()

# %% [markdown]
# # Challenges getting 20 random stocks from yfinance

# %%
import bs4 as bs
import requests
from random import randrange 
import random

# %%
resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
soup = bs.BeautifulSoup(resp.text, 'lxml')
table = soup.find('table', {'class': 'wikitable sortable'})

# %%
tickers = []

for row in table.findAll('tr')[1:]:
    ticker = row.findAll('td')[0].text
    tickers.append(ticker)

# %%
print(tickers)
# Out:
# ['MMM\n', 'AOS\n', 'ABT\n', 'ABBV\n', 'ACN\n', 'ATVI\n', 'ADM\n', 'ADBE\n', 'ADP\n', 'AES\n', 'AFL\n', 'A\n', 'APD\n', 'AKAM\n', 'ALK\n', 'ALB\n', 'ARE\n', 'ALGN\n', 'ALLE\n', 'LNT\n', 'ALL\n', 'GOOGL\n', 'GOOG\n', 'MO\n', 'AMZN\n', 'AMCR\n', 'AMD\n', 'AEE\n', 'AAL\n', 'AEP\n', 'AXP\n', 'AIG\n', 'AMT\n', 'AWK\n', 'AMP\n', 'ABC\n', 'AME\n', 'AMGN\n', 'APH\n', 'ADI\n', 'ANSS\n', 'AON\n', 'APA\n', 'AAPL\n', 'AMAT\n', 'APTV\n', 'ACGL\n', 'ANET\n', 'AJG\n', 'AIZ\n', 'T\n', 'ATO\n', 'ADSK\n', 'AZO\n', 'AVB\n', 'AVY\n', 'AXON\n', 'BKR\n', 'BALL\n', 'BAC\n', 'BBWI\n', 'BAX\n', 'BDX\n', 'WRB\n', 'BRK.B\n', 'BBY\n', 'BIO\n', 'TECH\n', 'BIIB\n', 'BLK\n', 'BK\n', 'BA\n', 'BKNG\n', 'BWA\n', 'BXP\n', 'BSX\n', 'BMY\n', 'AVGO\n', 'BR\n', 'BRO\n', 'BF.B\n', 'BG\n', 'CHRW\n', 'CDNS\n', 'CZR\n', 'CPT\n', 'CPB\n', 'COF\n', 'CAH\n', 'KMX\n', 'CCL\n', 'CARR\n', 'CTLT\n', 'CAT\n', 'CBOE\n', 'CBRE\n', 'CDW\n', 'CE\n', 'CNC\n', 'CNP\n', 'CDAY\n', 'CF\n', 'CRL\n', 'SCHW\n', 'CHTR\n', 'CVX\n', 'CMG\n', 'CB\n',
# ...

# %%
tickers = [s.replace('\n', '') for s in tickers]

# %%
sorted(tickers)
print(tickers)
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BG', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 
# ...

# %%
n = 20
random_tickers = random.sample(tickers, n)

# %%
print(random_tickers)
# Out:
# ['EXPD', 'AMGN', 'IVZ', 'XYL', 'FMC', 'GILD', 'WAB', 'MOH', 'HAS', 'AEE', 'NXPI', 'KEYS', 'DPZ', 'FTNT', 'UPS', 'UHS', 'CDAY', 'HRL', 'JPM', 'NEM']

# %%
df = yf.download(random_tickers, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  20 of 20 completed

# %%
df
# Out:
#             Adj Close                                                 \
#                   AEE        AMGN        CDAY         DPZ       EXPD
# Date
# 2010-01-04  16.775377   42.146587         NaN    7.174515  29.462786
# 2010-01-05  16.708899   41.781487         NaN    7.240641  29.664339
# 2010-01-06  16.594086   41.467510         NaN    7.447279  28.975655
# 2010-01-07  16.436972   41.087803         NaN    7.744838  28.799282
# 2010-01-08  16.322147   41.452892         NaN    7.744838  29.101641
# ...               ...         ...         ...         ...        ...
# 2020-12-24  71.456619  204.190292  110.059998  385.678253  92.096939
# 2020-12-28  71.718254  204.849731  106.669998  389.032166  92.671089
# 2020-12-29  71.550056  207.799057  107.059998  373.652802  92.116417
# 2020-12-30  71.923836  208.073868  105.400002  373.905670  92.038567
# 2020-12-31  72.942360  210.592697  106.559998  372.777985  92.554321
#
# ...

# %%
df.columns
# Out:
# MultiIndex([('Adj Close',  'AEE'),
#             ('Adj Close', 'AMGN'),
#             ('Adj Close', 'CDAY'),
#             ('Adj Close',  'DPZ'),
#             ('Adj Close', 'EXPD'),
#             ('Adj Close',  'FMC'),
#             ('Adj Close', 'FTNT'),
#             ('Adj Close', 'GILD'),
#             ('Adj Close',  'HAS'),
#             ('Adj Close',  'HRL'),
#             ...
#             (   'Volume',  'IVZ'),
#             (   'Volume',  'JPM'),
#             (   'Volume', 'KEYS'),
#             (   'Volume',  'MOH'),
#             (   'Volume',  'NEM'),
#             (   'Volume', 'NXPI'),
#             (   'Volume',  'UHS'),
#             (   'Volume',  'UPS'),
#             (   'Volume',  'WAB'),
#             (   'Volume',  'XYL')],
#            length=120)

# %%
closes = df.Close.resample('M').last() #only fetching the close prices from 20 columns

# %%
closes #dataframe that has
# Out:
#                   AEE        AMGN        CDAY         DPZ       EXPD  \
# Date
# 2010-01-31  25.549999   58.480000         NaN   11.300000  34.099998
# 2010-02-28  24.709999   56.610001         NaN   12.490000  36.470001
# 2010-03-31  26.080000   59.840000         NaN   13.640000  36.919998
# 2010-04-30  25.959999   57.310001         NaN   15.410000  40.709999
# 2010-05-31  24.660000   51.779999         NaN   13.000000  38.240002
# ...               ...         ...         ...         ...        ...
# 2020-08-31  79.110001  253.320007   79.519997  408.959991  88.389999
# 2020-09-30  79.080002  254.160004   82.650002  425.279999  90.519997
# 2020-10-31  81.120003  216.940002   86.220001  378.320007  88.370003
# 2020-11-30  77.779999  222.039993   96.419998  392.570007  89.370003
# 2020-12-31  78.059998  229.919998  106.559998  383.459991  95.110001
#
#                    FMC       FTNT       GILD        HAS        HRL        IVZ  \
# Date
# ...

# %%
closes['AEE'].iloc[0]
returns = dict()

# %%
for column in closes:
    ret= closes[column].pct_change().mul(100).dropna()
    print(ret)
    returns[column] = ret.mean()
# Out:
# Date
# 2010-02-28   -3.287672
# 2010-03-31    5.544318
# 2010-04-30   -0.460126
# 2010-05-31   -5.007701
# 2010-06-30   -3.609081
#                 ...
# 2020-08-31   -1.408272
# 2020-09-30   -0.037920
# 2020-10-31    2.579667
# 2020-11-30   -4.117362
# 2020-12-31    0.359988
# Freq: M, Name: AEE, Length: 131, dtype: float64
# Date
# 2010-02-28    -3.197673
# 2010-03-31     5.705705
# 2010-04-30    -4.227939
# 2010-05-31    -9.649280
# 2010-06-30     1.583622
#                 ...
# 2020-08-31     3.535378
# 2020-09-30     0.331595
# 2020-10-31   -14.644319
# 2020-11-30     2.350876
# 2020-12-31     3.548912
# Freq: M, Name: AMGN, Length: 131, dtype: float64
# Date
# 2018-05-31     9.309691
# 2018-06-30    -3.852844
# 2018-07-31    -1.295572
# 2018-08-31    17.521374
# 2018-09-30     9.168828
# 2018-10-31    -9.659761
# 2018-11-30     5.662359
# 2018-12-31   -14.032895
# 2019-01-31    19.483900
# 2019-02-28    18.951715
# 2019-03-31     4.651160
# 2019-04-30     3.606242
# ...

# %%
returns = sorted(returns.items(), key=lambda x:x[1])
#printout the 5best returns

# %%
top5_ret_stock = [x[0] for x in returns[-5:]]
top5_ret = [x[1] for x in returns[-5:]]

# %%
top5_ret = [ret*252 for ret in top5_ret] #top 5 retur
annual5_ret = top5_ret.copy()

# %%
top5_ret
# Out:
# [667.6040768400823,
#  694.5677358303133,
#  719.3827414520857,
#  759.3367111109251,
#  1144.2118515012887]

# %%
variance = dict()

# %%
for column in closes:
    ret = closes[column].pct_change().mul(100).dropna()
    variance[column] = ret.var()
variance = sorted(variance.items(), key=lambda x:x[1])
# Out:
# /var/folders/nf/0vtk3k494119zd0hw585mcqc0000gn/T/ipykernel_98053/2981509568.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   ret = closes[column].pct_change().mul(100).dropna()

# %%
top5_var_stock = [x[0] for x in variance[-5:]]
top5_var = [x[1] for x in variance[-5:]]

# %%
top5_std = [np.sqrt(var) for var in top5_var]

# %%
annual5_var = [var*252 for var in top5_var]
annual5_std = [std*np.sqrt(252) for std in top5_std]

# %%
annual5_var
# Out:
# [26228.094550659574,
#  28867.33291828855,
#  31337.95836199369,
#  33685.93223339127,
#  37469.18099062671]

# %%
annual5_std
# Out:
# [161.95090166670755,
#  169.90389318167067,
#  177.0253042985485,
#  183.53727750348503,
#  193.56957661426733]

# %%
#now get the normclose
normClose2 =  closes.div(closes.iloc[0]).mul(100)
normClose2.plot(figsize = (12, 8), fontsize = 12) #plotting the graph 
plt.legend(fontsize = 12) #ticker symbols
plt.show()

# %%
ret2 = closes.pct_change().dropna().mul(100)
# Out:
# /var/folders/nf/0vtk3k494119zd0hw585mcqc0000gn/T/ipykernel_98053/1274886181.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   ret2 = closes.pct_change().dropna().mul(100)

# %%
ret2
# Out:
#                   AEE       AMGN       CDAY        DPZ       EXPD        FMC  \
# Date
# 2018-05-31   0.972364   2.945896   9.309691   4.033426  16.630133   9.231165
# 2018-06-30   2.804528   2.766953  -3.852844  12.203761  -1.852853   2.434256
# 2018-07-31   1.988501   6.479228  -1.295572  -6.914275   4.199726   0.751037
# 2018-08-31   1.885269   1.658608  17.521374  13.667857  -3.794144  -4.928790
# 2018-09-30  -0.015813   3.743554   9.168828  -1.259382   0.341157   2.024577
# 2018-10-31   2.151219  -6.995031  -9.659761  -8.822924  -8.635929 -10.438176
# 2018-11-30   6.255808   8.019092   5.662359   3.173481  13.262870   5.968242
# 2018-12-31  -4.940250  -6.521009 -14.032895 -10.576230 -10.513866 -10.611559
# 2019-01-31   6.300771  -3.883494  19.483900  14.411873   1.777070   7.896161
# 2019-02-28   2.740123   1.587302  18.951715 -11.556764   8.152949  12.155386
# 2019-03-31   3.242568  -0.052613   4.651160   2.853273   1.267518  -1.035238
# ...

# %%
summary2 = ret2.describe().T.loc[:, ["mean", "std"]]

# %%
summary2
# Out:
#           mean        std
# AEE   0.985072   4.256693
# AMGN  1.111453   7.140567
# CDAY  4.540523  11.561762
# DPZ   1.791004   8.428843
# EXPD  1.469964   6.734482
# FMC   1.818579   6.729045
# FTNT  3.831889  12.387996
# GILD -0.441532   6.867033
# HAS   0.634763   9.435858
# HRL   0.931135   5.416277
# IVZ  -0.691646  13.265592
# JPM   0.817924   8.165468
# KEYS  3.362467   9.026257
# MOH   3.505736  10.648703
# NEM   1.672787   8.734225
# NXPI  1.949862  11.382882
# UHS   1.004874   9.357851
# UPS   1.670915   9.580674
# WAB   0.168918  12.226533
# XYL   1.380419   8.189550

# %%
summary2["mean"] = summary2["mean"] * 252
summary2["std"] = summary2["std"] * np.sqrt(252)

# %%
summary2
# Out:
#              mean         std
# AEE    248.238112   67.572914
# AMGN   280.086179  113.352990
# CDAY  1144.211852  183.537278
# DPZ    451.333065  133.803734
# EXPD   370.430934  106.906585
# FMC    458.281927  106.820275
# FTNT   965.636021  196.653345
# GILD  -111.266064  109.010772
# HAS    159.960261  149.789604
# HRL    234.646141   85.980731
# IVZ   -174.294830  210.584752
# JPM    206.116913  129.622785
# KEYS   847.341701  143.287381
# MOH    883.445496  169.042924
# NEM    421.542308  138.651517
# NXPI   491.365277  180.697648
# UHS    253.228209  148.551286
# UPS    421.070617  152.088491
# WAB     42.567213  194.090187
# XYL    347.865472  130.005076

# %%
summary2.plot.scatter(x = "std", y = "mean", figsize = (12, 8), s = 100, fontsize =15)
for index in summary2.index:
    plt.annotate(index, xy = (summary2.loc[index, "std"] + 0.0002, summary2.loc[index, "mean"] + 0.000),size = 10)
plt.xlabel("Annual risk(std):", fontsize =15)
plt.ylabel("Annual return(mean):", fontsize =15)
plt.title("Risk/return", fontsize = 25)
plt.show()

# %%
ret2.cov()
# Out:
#             AEE       AMGN        CDAY        DPZ       EXPD        FMC  \
# AEE   18.119439  -2.756004    8.306503   1.079374  10.063738   6.694531
# AMGN  -2.756004  50.987700   25.670788   8.899940  20.170231  25.106700
# CDAY   8.306503  25.670788  133.674334  15.895380  30.158971  48.479828
# DPZ    1.079374   8.899940   15.895380  71.045393   9.981857  14.748116
# EXPD  10.063738  20.170231   30.158971   9.981857  45.353246  33.965966
# FMC    6.694531  25.106700   48.479828  14.748116  33.965966  45.280044
# FTNT  -1.168679  23.028716   88.024322  18.926653  26.092446  33.736790
# GILD  -5.248825  20.671286    7.282563  27.684819   6.990196  15.490736
# HAS    5.450036   7.129386   34.614541  -1.619039  25.503704  27.798890
# HRL    5.788412   5.693136   -0.432263  -9.059706  -1.614873  -5.203885
# IVZ    0.538183  -4.637022   72.672574  -1.934390  25.840491  39.251590
# JPM    7.632175  14.800164   46.540403   9.738667  27.886314  36.852430
# ...

# %%
plt.figure(figsize = (12, 8))
sns.set(font_scale = 1.4)
sns.heatmap(ret2.corr(), cmap = "Reds", annot = True, annot_kws = {"size": 10}, vmax = 0.6 , fmt=".2f")
plt.show()

# %% [markdown]
# # Simple returns and log returns

# %%
df = pd.DataFrame(index = [2016,2017,2018], data = [100, 50, 95], columns = ["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean() * 2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   25.029381
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.207399
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.260803
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.527832
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.634628
# ...                ...         ...         ...         ...         ...
# 2023-08-28  442.239990  443.399994  439.970001  442.760010  442.760010
# 2023-08-29  442.649994  449.450012  442.459991  449.160004  449.160004
# 2023-08-30  449.510010  451.670013  448.779999  451.010010  451.010010
# 2023-08-31  451.649994  452.829987  450.160004  450.350006  450.350006
# 2023-09-01  453.170013  453.670013  449.679993  451.190002  451.190002
#
#               Volume
# Date
# 1993-01-29   1003200
# 1993-02-01    480500
# 1993-02-02    201300
# ...

# %%
spy = SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-08-28  442.760010
# 2023-08-29  449.160004
# 2023-08-30  451.010010
# 2023-08-31  450.350006
# 2023-09-01  451.190002
#
# [7704 rows x 1 columns]

# %%
spy.plot(figsize=(12, 8), fontsize =15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
spy_roll = spy.rolling(window = 10)

# %%
spy_roll = spy_roll.mean()

# %%
spy_roll.head()
# Out:
#             Close
# Date
# 1993-01-29    NaN
# 1993-02-01    NaN
# 1993-02-02    NaN
# 1993-02-03    NaN
# 1993-02-04    NaN

# %%
spy["SMA50"] = spy.rolling(window = 50, min_periods = 50).mean()

# %%
spy
# Out:
#                  Close       SMA50
# Date
# 1993-01-29   43.937500         NaN
# 1993-02-01   44.250000         NaN
# 1993-02-02   44.343750         NaN
# 1993-02-03   44.812500         NaN
# 1993-02-04   45.000000         NaN
# ...                ...         ...
# 2023-08-28  442.760010  444.766801
# 2023-08-29  449.160004  444.960801
# 2023-08-30  451.010010  445.237402
# 2023-08-31  450.350006  445.545602
# 2023-09-01  451.190002  445.839202
#
# [7704 rows x 2 columns]

# %%
spy.rolling(window = 2).mean()
# Out:
#                  Close       SMA50
# Date
# 1993-01-29         NaN         NaN
# 1993-02-01   44.093750         NaN
# 1993-02-02   44.296875         NaN
# 1993-02-03   44.578125         NaN
# 1993-02-04   44.906250         NaN
# ...                ...         ...
# 2023-08-28  441.365005  444.765201
# 2023-08-29  445.960007  444.863801
# 2023-08-30  450.085007  445.099102
# 2023-08-31  450.680008  445.391502
# 2023-09-01  450.770004  445.692402
#
# [7704 rows x 2 columns]

# %%
spy.rolling(window = 3).mean()
# Out:
#                  Close       SMA50
# Date
# 1993-01-29         NaN         NaN
# 1993-02-01         NaN         NaN
# 1993-02-02   44.177083         NaN
# 1993-02-03   44.468750         NaN
# 1993-02-04   44.718750         NaN
# ...                ...         ...
# 2023-08-28  439.873342  444.746068
# 2023-08-29  443.963338  444.830401
# 2023-08-30  447.643341  444.988335
# 2023-08-31  450.173340  445.247935
# 2023-09-01  450.850006  445.540735
#
# [7704 rows x 2 columns]

# %%
spy.rolling(window = 5, min_periods = 3).sum().head(15)
# Out:
#                 Close  SMA50
# Date
# 1993-01-29        NaN    NaN
# 1993-02-01        NaN    NaN
# 1993-02-02  132.53125    NaN
# 1993-02-03  177.34375    NaN
# 1993-02-04  222.34375    NaN
# 1993-02-05  223.37500    NaN
# 1993-02-08  224.09375    NaN
# 1993-02-09  224.40625    NaN
# 1993-02-10  224.31250    NaN
# 1993-02-11  224.25000    NaN
# 1993-02-12  223.87500    NaN
# 1993-02-16  222.37500    NaN
# 1993-02-17  221.15625    NaN
# 1993-02-18  219.84375    NaN
# 1993-02-19  218.46875    NaN

# %%
spy.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc="upper left", fontsize = 15)
plt.show()

# %%
spy["SMA200"] = spy.Close.rolling(window = 200, min_periods = 200).mean()

# %%
spy
# Out:
#                  Close       SMA50     SMA200
# Date
# 1993-01-29   43.937500         NaN        NaN
# 1993-02-01   44.250000         NaN        NaN
# 1993-02-02   44.343750         NaN        NaN
# 1993-02-03   44.812500         NaN        NaN
# 1993-02-04   45.000000         NaN        NaN
# ...                ...         ...        ...
# 2023-08-28  442.760010  444.766801  413.85720
# 2023-08-29  449.160004  444.960801  414.23235
# 2023-08-30  451.010010  445.237402  414.51395
# 2023-08-31  450.350006  445.545602  414.77315
# 2023-09-01  451.190002  445.839202  415.05350
#
# [7704 rows x 3 columns]

# %%
spy.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc= "upper left", fontsize = 15)
plt.show()

# %%
spy["EMA100"] = spy.Close.ewm(span = 100, min_periods = 100).mean()

# %%
spy
# Out:
#                  Close       SMA50     SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN
# 1993-02-01   44.250000         NaN        NaN         NaN
# 1993-02-02   44.343750         NaN        NaN         NaN
# 1993-02-03   44.812500         NaN        NaN         NaN
# 1993-02-04   45.000000         NaN        NaN         NaN
# ...                ...         ...        ...         ...
# 2023-08-28  442.760010  444.766801  413.85720  432.422149
# 2023-08-29  449.160004  444.960801  414.23235  432.753592
# 2023-08-30  451.010010  445.237402  414.51395  433.115105
# 2023-08-31  450.350006  445.545602  414.77315  433.456390
# 2023-09-01  451.190002  445.839202  415.05350  433.807551
#
# [7704 rows x 4 columns]

# %%
spy.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc= "upper left", fontsize = 15)
plt.show()

# %%
spy["Day"] = spy.index.day_name() #returns days such as Mon, Tue, Wed, Thur, Fri, Sat, Sun
spy["Quarter"] = spy.
